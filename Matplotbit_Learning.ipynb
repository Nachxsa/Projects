# %% [markdown]
# <a href="https://colab.research.google.com/github/Nachxsa/Projects/blob/main/Matplotbit_Learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
# # Create a graphic with numpy
# # X_data = np.random.random(1000)*100
# # Y_data = np.random.random(100)*100

'''Scattered graphic'''
# # plt.scatter(X_data, Y_data, c='c', marker='*', s=100, alpha=0.2) #c: color, marker: dot design, alpha: makes the dots like transparebt

# #Data for plots
# # years = [2006 + x for x in range(16)]
# # weights = [60 + x + 1 for x in range(16)]
# x = ['C++', 'C#', 'Python', 'Java', 'Go']
# y = [20, 50, 140, 1, 45]
age = np.random.normal(20, 1.5, 1000)

'''Connected graphic'''
# # plt.plot(years, weights, lw=2, linestyle='--') #lw: linewidth, linestyle:line style

'''Bar graphic'''
# plt.bar(x, y, align='edge', width=0.1, edgecolor='black')
# '''align: donde va a estar la barra en relación al texto que tiene abajo
# edgecolor: color del borde
# with: tamaño de cada barra'''

'''Histograms'''
ages = np.random.normal(20, 1.5, 1000)
# '''Media (20): Los valores generados estarán centrados en 20 años.
# Desviación estándar (1.5): Cuánto varían los datos en promedio respecto a la media.
# 1000: Se generan 1000 edades simuladas.'''
# plt.hist(ages,
#          bins=20,
#          cumulative=True,) #Cumulative, como que se acumula el valor y lo pone como d menor a mayor
# # Specifying bins: bins=[ages.min(), 18, 21, ages.max()]
# plt.show()

'''Pie graphic'''
# langs = ['C++', 'C#', 'Python', 'Java', 'Go']
# votes = [50, 24, 14, 6, 17]
# explodes = [0,0,0,0.2,0]
# plt.pie(votes, labels=langs,
#         explode=explodes, #explode: uando la lista explodes, podés como que resaltar algna parte dejandola un poco afuera de grafico
#         autopct="%.0f%%", #autopct= permite poner los porcentjaes. EL  numero permite poner la cantidad de decimales
#         pctdistance=0.8) # El pctdistance: permite cambiar la distancia del porcentaje respecto al gráfico


'''Boxplots'''
# heights = np.random.normal(172, 8, 300)
# plt.boxplot(heights)
# plt.show()

'''Plot Customization'''
# Stylesheets
from matplotlib import style
style.use('dark_background')

#Data for the plot
years = [2014 + x for x in range(8)]
income = [55,56,62,61,72,72,73,75]
income_ticks = list(range(50,81,2))
print(income_ticks)
plt.plot(years, income, label='Company1')

# Set title
plt.title('Income of John (in USD)')
# Set x and y label
plt.xlabel('Year')
plt.ylabel('Income in USD Dollars')
# Modifiy the values in the y_ticks
plt.yticks(ticks=income_ticks, # The values we want to put in the y axis
           labels=[f'{x}k USD' for x in income_ticks],
           size=14) # The labels for those values in the y axis

# Add legend (for different graphs)
plt.legend(loc='center') #Loc: permite localizarlo en el graph

plt.show()

'''Multiple figures'''
#To create multiple figures use plt.figure to define many figures

'''Subplot'''
x = np.arange(100)
fig, axs = plt.subplots(2, 2)

axs[0,0].plot(x, np.sin(x))
axs[0, 0].set_title("Sine Wave")

axs[0,1].plot(x, np.cos(x))
axs[0, 0].set_title("Cosine wave")

axs[1,0].plot(x, np.tan(x))
axs[0, 0].set_title("Random Function")


'''Plots with Multiple Data'''
plt.figure(figsize=(14,8), dpi=120) #dpi=resolution
plt.title('Tesla Web Search vs Price', fontsize=18)

ax1 = plt.gca() # Get current Axis
ax2 = ax1.twinx() # Clone the axis to use a second one

# Set up the y axis for both parts
ax1.set_ylabel('TSLA Stock Price', color='#E6232E', fontsize=14)
ax2.set_ylabel('Search Trend', color='skyblue', fontsize=14)

# Set the minimum and maximum limits on the axis
ax1.set_ylim([0, 600])
ax1.set_xlim([df_tesla.MONTH.min(), df_tesla.MONTH.max()])

ax1.plot(df_tesla.MONTH, df_tesla.TSLA_USD_CLOSE, color='#E6232E', linewidth=3)
ax2.plot(df_tesla.MONTH, df_tesla.TSLA_WEB_SEARCH, color='skyblue', linewidth=3)

plt.show()
# Out:
# [50, 52, 54, 56, 58, 60, 62, 64, 66, 68, 70, 72, 74, 76, 78, 80]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-00d40d697577> in <cell line: 0>()
#     107 # Set the minimum and maximum limits on the axis
#     108 ax1.set_ylim([0, 600])
# --> 109 ax1.set_xlim([df_tesla.MONTH.min(), df_tesla.MONTH.max()])
#     110
#     111
#
# NameError: name 'df_tesla' is not defined
